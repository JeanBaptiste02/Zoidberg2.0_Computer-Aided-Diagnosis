# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns

# %%
if tf.config.list_physical_devices('GPU'):
    print("GPU détecté.")
else:
    print("Aucun GPU détecté, l'entraînement se fera sur le CPU.")
# Out:
# Aucun GPU détecté, l'entraînement se fera sur le CPU.

# %%
img_size = 150
padding_size = 20
batch_size = 32
epochs = 20
data_dir1 = '../../../chest_xray/train/PNEUMONIA'
data_dir2 = '../../../chest_xray/train/NORMAL'

# %%
def load_data(data_dir1, data_dir2, limit=100):
    print("Loading data...")
    data = []
    labels = ['PNEUMONIA', 'NORMAL']
    for dir in [data_dir1, data_dir2]:
        path = os.path.join(dir)
        if not os.path.exists(path):
            print(f"Le répertoire {path} n'existe pas")
            continue
        label = os.path.basename(dir)
        class_num = labels.index(label)
        for i, img in enumerate(os.listdir(path)):
            if i >= limit:
                break
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                if img_arr is None:
                    print(f"Failed to read {img}. Skipping.")
                    continue
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    print("Finished loading data.")
    return np.array(data, dtype=object)

# Charger les données
train_data = load_data(data_dir1, data_dir2, limit=100)
# Out:
# Loading data...
# Finished loading data.

# %%
# Fonction pour séparer les caractéristiques et les labels
def separate_features_labels(data):
    print("Separating features and labels...")
    features = []
    labels = []
    for img, label in data:
        features.append(img)
        labels.append(label)
    return np.array(features), np.array(labels)

# Fonction pour prétraiter les images avec padding
def preprocess_image(image):
    if len(image.shape) == 2:
        image = np.expand_dims(image, axis=-1)
    image = tf.image.resize(image, [img_size + 2 * padding_size, img_size + 2 * padding_size])
    image = image / 255.0  # Normalisation après redimensionnement
    return image

# Prétraiter les données
def preprocess_data(data):
    print("Preprocessing data...")
    processed_data = []
    for idx, (img, label) in enumerate(data):
        print(f"Processing image {idx+1}/{len(data)}")
        img = preprocess_image(img)
        processed_data.append([img, label])
    return np.array(processed_data, dtype=object)

train_data = preprocess_data(train_data)
x_train, y_train = separate_features_labels(train_data)
x_train = x_train.reshape(-1, img_size + 2 * padding_size, img_size + 2 * padding_size, 1)
x_train = np.concatenate([x_train, x_train, x_train], axis=-1)  # Convertir en 3 canaux

# Diviser les données en ensembles d'entraînement et de validation
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)
# Out:
# Preprocessing data...
# Processing image 1/200
# Processing image 2/200
# Processing image 3/200
# Processing image 4/200
# Processing image 5/200
# Processing image 6/200
# Processing image 7/200
# Processing image 8/200
# Processing image 9/200
# Processing image 10/200
# Processing image 11/200
# Processing image 12/200
# Processing image 13/200
# Processing image 14/200
# Processing image 15/200
# Processing image 16/200
# Processing image 17/200
# Processing image 18/200
# Processing image 19/200
# Processing image 20/200
# Processing image 21/200
# Processing image 22/200
# Processing image 23/200
# Processing image 24/200
# Processing image 25/200
# Processing image 26/200
# Processing image 27/200
# Processing image 28/200
# Processing image 29/200
# Processing image 30/200
# Processing image 31/200
# Processing image 32/200
# Processing image 33/200
# Processing image 34/200
# Processing image 35/200
# Processing image 36/200
# Processing image 37/200
# Processing image 38/200
# Processing image 39/200
# Processing image 40/200
# Processing image 41/200
# Processing image 42/200
# Processing image 43/200
# Processing image 44/200
# Processing image 45/200
# Processing image 46/200
# Processing image 47/200
# Processing image 48/200
# Processing image 49/200
# Processing image 50/200
# Processing image 51/200
# Processing image 52/200
# Processing image 53/200
# Processing image 54/200
# Processing image 55/200
# Processing image 56/200
# Processing image 57/200
# Processing image 58/200
# Processing image 59/200
# Processing image 60/200
# Processing image 61/200
# Processing image 62/200
# Processing image 63/200
# Processing image 64/200
# Processing image 65/200
# Processing image 66/200
# Processing image 67/200
# Processing image 68/200
# Processing image 69/200
# Processing image 70/200
# Processing image 71/200
# Processing image 72/200
# Processing image 73/200
# Processing image 74/200
# Processing image 75/200
# Processing image 76/200
# Processing image 77/200
# Processing image 78/200
# Processing image 79/200
# Processing image 80/200
# Processing image 81/200
# Processing image 82/200
# Processing image 83/200
# Processing image 84/200
# Processing image 85/200
# Processing image 86/200
# Processing image 87/200
# Processing image 88/200
# Processing image 89/200
# Processing image 90/200
# Processing image 91/200
# Processing image 92/200
# Processing image 93/200
# Processing image 94/200
# Processing image 95/200
# Processing image 96/200
# Processing image 97/200
# Processing image 98/200
# Processing image 99/200
# Processing image 100/200
# Processing image 101/200
# Processing image 102/200
# Processing image 103/200
# Processing image 104/200
# Processing image 105/200
# Processing image 106/200
# Processing image 107/200
# Processing image 108/200
# Processing image 109/200
# Processing image 110/200
# Processing image 111/200
# Processing image 112/200
# Processing image 113/200
# Processing image 114/200
# Processing image 115/200
# Processing image 116/200
# Processing image 117/200
# Processing image 118/200
# Processing image 119/200
# Processing image 120/200
# Processing image 121/200
# Processing image 122/200
# Processing image 123/200
# Processing image 124/200
# Processing image 125/200
# Processing image 126/200
# Processing image 127/200
# Processing image 128/200
# Processing image 129/200
# Processing image 130/200
# Processing image 131/200
# Processing image 132/200
# Processing image 133/200
# Processing image 134/200
# Processing image 135/200
# Processing image 136/200
# Processing image 137/200
# Processing image 138/200
# Processing image 139/200
# Processing image 140/200
# Processing image 141/200
# Processing image 142/200
# Processing image 143/200
# Processing image 144/200
# Processing image 145/200
# Processing image 146/200
# Processing image 147/200
# Processing image 148/200
# Processing image 149/200
# Processing image 150/200
# Processing image 151/200
# Processing image 152/200
# Processing image 153/200
# Processing image 154/200
# Processing image 155/200
# Processing image 156/200
# Processing image 157/200
# Processing image 158/200
# Processing image 159/200
# Processing image 160/200
# Processing image 161/200
# Processing image 162/200
# Processing image 163/200
# Processing image 164/200
# Processing image 165/200
# Processing image 166/200
# Processing image 167/200
# Processing image 168/200
# Processing image 169/200
# Processing image 170/200
# Processing image 171/200
# Processing image 172/200
# Processing image 173/200
# Processing image 174/200
# Processing image 175/200
# Processing image 176/200
# Processing image 177/200
# Processing image 178/200
# Processing image 179/200
# Processing image 180/200
# Processing image 181/200
# Processing image 182/200
# Processing image 183/200
# Processing image 184/200
# Processing image 185/200
# Processing image 186/200
# Processing image 187/200
# Processing image 188/200
# Processing image 189/200
# Processing image 190/200
# Processing image 191/200
# Processing image 192/200
# Processing image 193/200
# Processing image 194/200
# Processing image 195/200
# Processing image 196/200
# Processing image 197/200
# Processing image 198/200
# Processing image 199/200
# Processing image 200/200
# Separating features and labels...

# %%
# Initialiser ImageDataGenerator
print("Initializing ImageDataGenerator...")
datagen = ImageDataGenerator(
    zoom_range=0.1,
    shear_range=0.1
)
print("ImageDataGenerator initialized")
# Out:
# Initializing ImageDataGenerator...
# ImageDataGenerator initialized

# %%
# Ajuster ImageDataGenerator sur x_train
print("Fitting ImageDataGenerator on x_train...")
datagen.fit(x_train)
print("ImageDataGenerator fitting complete.")

# Fonction pour afficher les images augmentées
def display_augmented_images(datagen, x_train, y_train):
    print("Generating augmented images...")
    plt.figure(figsize=(10, 10))
    for x_batch, y_batch in datagen.flow(x_train, y_train, batch_size=5):
        for i in range(5):
            plt.subplot(330 + 1 + i)
            plt.xticks([])
            plt.yticks([])
            plt.imshow(x_batch[i].reshape(img_size + 2 * padding_size, img_size + 2 * padding_size, 3))
        plt.show()
        break

display_augmented_images(datagen, x_train, y_train)
# Out:
# Fitting ImageDataGenerator on x_train...
# ImageDataGenerator fitting complete.
# Generating augmented images...

# %%
# Définir le modèle
print("Defining the model...")

base_model = tf.keras.applications.VGG16(input_shape=(img_size + 2 * padding_size, img_size + 2 * padding_size, 3),
                                         include_top=False,
                                         weights='imagenet')
base_model.trainable = False  # Geler les couches du modèle de base

model = Sequential([
    base_model,
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

print("Model defined.")
print("Compiling the model...")

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

print("Model compiled")
model.build(input_shape=(None, img_size + 2 * padding_size, img_size + 2 * padding_size, 3))

print("Model built")
print("Model summary:")
print(model.summary())
# Out:
# Defining the model...
# Model defined.
# Compiling the model...
# Model compiled
# Model built
# Model summary:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 5, 5, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     1,638,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,353,345 (62.38 MB)
#  Trainable params: 1,638,657 (6.25 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.0001)
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
print("Starting training...")
history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    epochs=epochs,
                    validation_data=(x_val, y_val),
                    callbacks=[reduce_lr, early_stop])
print("Training complete.")
# Out:
# Starting training...
# Epoch 1/20
# C:\Users\vikne\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - accuracy: 0.6371 - loss: 0.7183 - val_accuracy: 0.7250 - val_loss: 0.4928 - learning_rate: 0.0010
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 31s 6s/step - accuracy: 0.7801 - loss: 0.5268 - val_accuracy: 0.9750 - val_loss: 0.1067 - learning_rate: 0.0010
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 6s/step - accuracy: 0.8770 - loss: 0.2577 - val_accuracy: 0.9500 - val_loss: 0.0978 - learning_rate: 0.0010
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 0.9411 - loss: 0.1418 - val_accuracy: 0.9750 - val_loss: 0.0918 - learning_rate: 0.0010
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 6s/step - accuracy: 0.9363 - loss: 0.1360 - val_accuracy: 0.9750 - val_loss: 0.0631 - learning_rate: 0.0010
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 6s/step - accuracy: 0.9446 - loss: 0.1887 - val_accuracy: 0.9750 - val_loss: 0.0927 - learning_rate: 0.0010
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.9744 - loss: 0.0994 - val_accuracy: 1.0000 - val_loss: 0.0508 - learning_rate: 0.0010
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.9689 - loss: 0.0844 - val_accuracy: 0.9750 - val_loss: 0.0460 - learning_rate: 0.0010
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 0.9872 - loss: 0.0346 - val_accuracy: 0.9750 - val_loss: 0.0615 - learning_rate: 0.0010
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 6s/step - accuracy: 0.9760 - loss: 0.0642 - val_accuracy: 1.0000 - val_loss: 0.0384 - learning_rate: 0.0010
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.9937 - loss: 0.0428 - val_accuracy: 1.0000 - val_loss: 0.0391 - learning_rate: 0.0010
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 0.9773 - loss: 0.0716 - val_accuracy: 0.9750 - val_loss: 0.1106 - learning_rate: 0.0010
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.9768 - loss: 0.0624 - val_accuracy: 1.0000 - val_loss: 0.0336 - learning_rate: 0.0010
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 42s 6s/step - accuracy: 0.9932 - loss: 0.0329 - val_accuracy: 1.0000 - val_loss: 0.0416 - learning_rate: 0.0010
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.9750 - val_loss: 0.0355 - learning_rate: 0.0010
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.9872 - loss: 0.0456 - val_accuracy: 1.0000 - val_loss: 0.0311 - learning_rate: 0.0010
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.9966 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 0.0248 - learning_rate: 0.0010
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 29s 5s/step - accuracy: 0.9945 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0235 - learning_rate: 0.0010
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 30s 6s/step - accuracy: 1.0000 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0301 - learning_rate: 0.0010
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 0.0277 - learning_rate: 0.0010
# Training complete.

# %%
def plot_learning_curves(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_learning_curves(history)

# %%
scores = model.evaluate(x_val, y_val, verbose=0)
print(f"Validation accuracy: {scores[1]*100:.2f}%")
print(f"Validation loss: {scores[0]:.4f}")
# Out:
# Validation accuracy: 100.00%
# Validation loss: 0.0235

# %%
def display_predictions(model, x_train, y_train):
    print("Début de l'affichage des prédictions...")
    predictions = model.predict(x_train)
    predictions = (predictions > 0.5).astype("int32")
    plt.figure(figsize=(10, 10))
    for i in range(9):
        plt.subplot(330 + 1 + i)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(x_train[i].reshape(img_size + 2 * padding_size, img_size + 2 * padding_size, 3))
        pred_label = predictions[i][0]
        true_label = y_train[i]
        plt.title(f"Pred: {pred_label}, True: {true_label}")
    plt.show()
    print("Affichage des prédictions terminé.")

display_predictions(model, x_train, y_train)
# Out:
# Début de l'affichage des prédictions...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step
# Affichage des prédictions terminé.

# %%
y_pred = (model.predict(x_train) > 0.5).astype("int32")
cm = confusion_matrix(y_train, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['PNEUMONIA', 'NORMAL'], yticklabels=['PNEUMONIA', 'NORMAL'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
print("Another way of representation of the Confusion Matrix:\n", cm)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 4s/step
# Another way of representation of the Confusion Matrix:
#  [[79  0]
#  [ 0 81]]

# %%
cr = classification_report(y_train, y_pred, target_names=['PNEUMONIA', 'NORMAL'])
print("Classification Report:\n", cr)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#    PNEUMONIA       1.00      1.00      1.00        79
#       NORMAL       1.00      1.00      1.00        81
#
#     accuracy                           1.00       160
#    macro avg       1.00      1.00      1.00       160
# weighted avg       1.00      1.00      1.00       160

# %%
fpr, tpr, _ = roc_curve(y_train, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
def display_predictions_simple(model, x_train, y_train, num_images=5):
    predictions = (model.predict(x_train) > 0.5).astype("int32")
    plt.figure(figsize=(10, 10))
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(x_train[i].reshape(img_size + 2 * padding_size, img_size + 2 * padding_size, 3))
        pred_label = predictions[i][0]
        true_label = y_train[i]
        color = 'green' if pred_label == true_label else 'red'
        plt.title(f"Pred: {pred_label}, True: {true_label}", color=color)
    plt.show()

display_predictions_simple(model, x_train, y_train, num_images=5)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step

# %%
def plot_prediction_histogram(model, x_data):
    predictions = model.predict(x_data).flatten()
    print(f"Nombre total de prédictions: {len(predictions)}")
    print(f"Valeur minimale des prédictions: {predictions.min():.4f}")
    print(f"Valeur maximale des prédictions: {predictions.max():.4f}")
    print(f"Moyenne des prédictions: {predictions.mean():.4f}")
    print(f"Médiane des prédictions: {np.median(predictions):.4f}")
    print(f"Écart-type des prédictions: {predictions.std():.4f}")

    counts, bin_edges = np.histogram(predictions, bins=20)
    for i in range(len(counts)):
        print(f"Bin {i+1}: {bin_edges[i]:.2f} - {bin_edges[i+1]:.2f}, Nombre d'images: {counts[i]}")

    plt.hist(predictions, bins=20, color='blue', alpha=0.7)
    plt.xlabel('Probabilité prédite')
    plt.ylabel('Nombre d\'images')
    plt.title('Distribution des Prédictions')
    plt.show()
    
plot_prediction_histogram(model, x_train)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 20s 4s/step
# Nombre total de prédictions: 160
# Valeur minimale des prédictions: 0.0000
# Valeur maximale des prédictions: 1.0000
# Moyenne des prédictions: 0.5130
# Médiane des prédictions: 0.9865
# Écart-type des prédictions: 0.4922
# Bin 1: 0.00 - 0.05, Nombre d'images: 72
# Bin 2: 0.05 - 0.10, Nombre d'images: 5
# Bin 3: 0.10 - 0.15, Nombre d'images: 0
# Bin 4: 0.15 - 0.20, Nombre d'images: 1
# Bin 5: 0.20 - 0.25, Nombre d'images: 0
# Bin 6: 0.25 - 0.30, Nombre d'images: 1
# Bin 7: 0.30 - 0.35, Nombre d'images: 0
# Bin 8: 0.35 - 0.40, Nombre d'images: 0
# Bin 9: 0.40 - 0.45, Nombre d'images: 0
# Bin 10: 0.45 - 0.50, Nombre d'images: 0
# Bin 11: 0.50 - 0.55, Nombre d'images: 0
# Bin 12: 0.55 - 0.60, Nombre d'images: 0
# Bin 13: 0.60 - 0.65, Nombre d'images: 0
# Bin 14: 0.65 - 0.70, Nombre d'images: 0
# Bin 15: 0.70 - 0.75, Nombre d'images: 0
# Bin 16: 0.75 - 0.80, Nombre d'images: 0
# Bin 17: 0.80 - 0.85, Nombre d'images: 0
# Bin 18: 0.85 - 0.90, Nombre d'images: 0
# Bin 19: 0.90 - 0.95, Nombre d'images: 0
# Bin 20: 0.95 - 1.00, Nombre d'images: 81

# %%
def print_predictions_table(model, x_data, y_data, num_samples=10):
    probs = model.predict(x_data).flatten()
    predictions = (probs > 0.5).astype("int32")
    print(f"{'Index':<6}{'Prédiction':<12}{'Probabilité':<12}{'Vrai Label':<12}{'Correct':<8}")
    print("-" * 60)
    for i in range(num_samples):
        correct = 'Oui' if predictions[i] == y_data[i] else 'Non'
        print(f"{i:<6}{predictions[i]:<12}{probs[i]:<12.4f}{y_data[i]:<12}{correct:<8}")

print_predictions_table(model, x_train, y_train)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step
# Index Prédiction  Probabilité Vrai Label  Correct
# ------------------------------------------------------------
# 0     0           0.0001      0           Oui
# 1     1           0.9991      1           Oui
# 2     0           0.0526      0           Oui
# 3     0           0.0000      0           Oui
# 4     1           0.9980      1           Oui
# 5     1           0.9990      1           Oui
# 6     0           0.0000      0           Oui
# 7     0           0.0001      0           Oui
# 8     1           1.0000      1           Oui
# 9     0           0.0005      0           Oui
