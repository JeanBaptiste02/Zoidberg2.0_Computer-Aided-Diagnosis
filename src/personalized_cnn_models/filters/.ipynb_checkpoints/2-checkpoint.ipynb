# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns

# %%
print("Vérification GPU...")
if tf.config.list_physical_devices('GPU'):
    print("GPU détecté.")
else:
    print("Aucun GPU détecté, l'entraînement se fera sur le CPU.")
# Out:
# Vérification GPU...
# Aucun GPU détecté, l'entraînement se fera sur le CPU.

# %%
img_size = 128
batch_size = 32
epochs = 20
data_dir1 = '../../../chest_xray/train/PNEUMONIA'
data_dir2 = '../../../chest_xray/train/NORMAL'
n_folds = 10

# %%
def load_data(data_dir1, data_dir2, limit=100):
    print("Chargement des données...")
    data = []
    labels = ['PNEUMONIA', 'NORMAL']
    for dir in [data_dir1, data_dir2]:
        path = os.path.join(dir)
        if not os.path.exists(path):
            print(f"Le répertoire {path} n'existe pas")
            continue
        label = os.path.basename(dir)
        class_num = labels.index(label)
        for i, img in enumerate(os.listdir(path)):
            if i >= limit:
                break
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                if img_arr is None:
                    print(f"Échec de la lecture de {img}. Passage au suivant.")
                    continue
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    print("Chargement des données terminé.")
    return np.array(data, dtype=object)

train_data = load_data(data_dir1, data_dir2, limit=100)
# Out:
# Chargement des données...
# Chargement des données terminé.

# %%
# Prétraitement des images
def preprocess_image(image):
    if len(image.shape) == 2:
        image = np.expand_dims(image, axis=-1)
    image = tf.image.resize(image, [img_size, img_size])
    image = image / 255.0  # Normalisation
    return image

# Prétraitement des données
def preprocess_data(data):
    print("Prétraitement des données...")
    processed_data = []
    for idx, (img, label) in enumerate(data):
        print(f"Traitement de l'image {idx+1}/{len(data)}")
        img = preprocess_image(img)
        processed_data.append([img, label])
    return np.array(processed_data, dtype=object)

train_data = preprocess_data(train_data)
# Out:
# Prétraitement des données...
# Traitement de l'image 1/200
# Traitement de l'image 2/200
# Traitement de l'image 3/200
# Traitement de l'image 4/200
# Traitement de l'image 5/200
# Traitement de l'image 6/200
# Traitement de l'image 7/200
# Traitement de l'image 8/200
# Traitement de l'image 9/200
# Traitement de l'image 10/200
# Traitement de l'image 11/200
# Traitement de l'image 12/200
# Traitement de l'image 13/200
# Traitement de l'image 14/200
# Traitement de l'image 15/200
# Traitement de l'image 16/200
# Traitement de l'image 17/200
# Traitement de l'image 18/200
# Traitement de l'image 19/200
# Traitement de l'image 20/200
# Traitement de l'image 21/200
# Traitement de l'image 22/200
# Traitement de l'image 23/200
# Traitement de l'image 24/200
# Traitement de l'image 25/200
# Traitement de l'image 26/200
# Traitement de l'image 27/200
# Traitement de l'image 28/200
# Traitement de l'image 29/200
# Traitement de l'image 30/200
# Traitement de l'image 31/200
# Traitement de l'image 32/200
# Traitement de l'image 33/200
# Traitement de l'image 34/200
# Traitement de l'image 35/200
# Traitement de l'image 36/200
# Traitement de l'image 37/200
# Traitement de l'image 38/200
# Traitement de l'image 39/200
# Traitement de l'image 40/200
# Traitement de l'image 41/200
# Traitement de l'image 42/200
# Traitement de l'image 43/200
# Traitement de l'image 44/200
# Traitement de l'image 45/200
# Traitement de l'image 46/200
# Traitement de l'image 47/200
# Traitement de l'image 48/200
# Traitement de l'image 49/200
# Traitement de l'image 50/200
# Traitement de l'image 51/200
# Traitement de l'image 52/200
# Traitement de l'image 53/200
# Traitement de l'image 54/200
# Traitement de l'image 55/200
# Traitement de l'image 56/200
# Traitement de l'image 57/200
# Traitement de l'image 58/200
# Traitement de l'image 59/200
# Traitement de l'image 60/200
# Traitement de l'image 61/200
# Traitement de l'image 62/200
# Traitement de l'image 63/200
# Traitement de l'image 64/200
# Traitement de l'image 65/200
# Traitement de l'image 66/200
# Traitement de l'image 67/200
# Traitement de l'image 68/200
# Traitement de l'image 69/200
# Traitement de l'image 70/200
# Traitement de l'image 71/200
# Traitement de l'image 72/200
# Traitement de l'image 73/200
# Traitement de l'image 74/200
# Traitement de l'image 75/200
# Traitement de l'image 76/200
# Traitement de l'image 77/200
# Traitement de l'image 78/200
# Traitement de l'image 79/200
# Traitement de l'image 80/200
# Traitement de l'image 81/200
# Traitement de l'image 82/200
# Traitement de l'image 83/200
# Traitement de l'image 84/200
# Traitement de l'image 85/200
# Traitement de l'image 86/200
# Traitement de l'image 87/200
# Traitement de l'image 88/200
# Traitement de l'image 89/200
# Traitement de l'image 90/200
# Traitement de l'image 91/200
# Traitement de l'image 92/200
# Traitement de l'image 93/200
# Traitement de l'image 94/200
# Traitement de l'image 95/200
# Traitement de l'image 96/200
# Traitement de l'image 97/200
# Traitement de l'image 98/200
# Traitement de l'image 99/200
# Traitement de l'image 100/200
# Traitement de l'image 101/200
# Traitement de l'image 102/200
# Traitement de l'image 103/200
# Traitement de l'image 104/200
# Traitement de l'image 105/200
# Traitement de l'image 106/200
# Traitement de l'image 107/200
# Traitement de l'image 108/200
# Traitement de l'image 109/200
# Traitement de l'image 110/200
# Traitement de l'image 111/200
# Traitement de l'image 112/200
# Traitement de l'image 113/200
# Traitement de l'image 114/200
# Traitement de l'image 115/200
# Traitement de l'image 116/200
# Traitement de l'image 117/200
# Traitement de l'image 118/200
# Traitement de l'image 119/200
# Traitement de l'image 120/200
# Traitement de l'image 121/200
# Traitement de l'image 122/200
# Traitement de l'image 123/200
# Traitement de l'image 124/200
# Traitement de l'image 125/200
# Traitement de l'image 126/200
# Traitement de l'image 127/200
# Traitement de l'image 128/200
# Traitement de l'image 129/200
# Traitement de l'image 130/200
# Traitement de l'image 131/200
# Traitement de l'image 132/200
# Traitement de l'image 133/200
# Traitement de l'image 134/200
# Traitement de l'image 135/200
# Traitement de l'image 136/200
# Traitement de l'image 137/200
# Traitement de l'image 138/200
# Traitement de l'image 139/200
# Traitement de l'image 140/200
# Traitement de l'image 141/200
# Traitement de l'image 142/200
# Traitement de l'image 143/200
# Traitement de l'image 144/200
# Traitement de l'image 145/200
# Traitement de l'image 146/200
# Traitement de l'image 147/200
# Traitement de l'image 148/200
# Traitement de l'image 149/200
# Traitement de l'image 150/200
# Traitement de l'image 151/200
# Traitement de l'image 152/200
# Traitement de l'image 153/200
# Traitement de l'image 154/200
# Traitement de l'image 155/200
# Traitement de l'image 156/200
# Traitement de l'image 157/200
# Traitement de l'image 158/200
# Traitement de l'image 159/200
# Traitement de l'image 160/200
# Traitement de l'image 161/200
# Traitement de l'image 162/200
# Traitement de l'image 163/200
# Traitement de l'image 164/200
# Traitement de l'image 165/200
# Traitement de l'image 166/200
# Traitement de l'image 167/200
# Traitement de l'image 168/200
# Traitement de l'image 169/200
# Traitement de l'image 170/200
# Traitement de l'image 171/200
# Traitement de l'image 172/200
# Traitement de l'image 173/200
# Traitement de l'image 174/200
# Traitement de l'image 175/200
# Traitement de l'image 176/200
# Traitement de l'image 177/200
# Traitement de l'image 178/200
# Traitement de l'image 179/200
# Traitement de l'image 180/200
# Traitement de l'image 181/200
# Traitement de l'image 182/200
# Traitement de l'image 183/200
# Traitement de l'image 184/200
# Traitement de l'image 185/200
# Traitement de l'image 186/200
# Traitement de l'image 187/200
# Traitement de l'image 188/200
# Traitement de l'image 189/200
# Traitement de l'image 190/200
# Traitement de l'image 191/200
# Traitement de l'image 192/200
# Traitement de l'image 193/200
# Traitement de l'image 194/200
# Traitement de l'image 195/200
# Traitement de l'image 196/200
# Traitement de l'image 197/200
# Traitement de l'image 198/200
# Traitement de l'image 199/200
# Traitement de l'image 200/200

# %%
# Séparation des caractéristiques et étiquettes
def separate_features_labels(data):
    images = np.array([item[0] for item in data])
    labels = np.array([item[1] for item in data])
    return images, labels

x_train, y_train = separate_features_labels(train_data)
x_train = x_train.reshape(-1, img_size, img_size, 1)
x_train = np.concatenate([x_train, x_train, x_train], axis=-1)

# %%
# Définition du modèle CNN
def create_model():
    print("Définition du modèle...")
    model = Sequential([
        Conv2D(2, (3, 3), activation='relu', input_shape=(img_size, img_size, 3)),
        MaxPooling2D((2, 2)),
        Conv2D(4, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(8, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(16, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    print("Modèle défini.")
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
                  loss='binary_crossentropy', 
                  metrics=['accuracy'])
    print("Modèle compilé")
    return model

# Validation croisée K-Fold
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
fold = 1
fold_accuracies = []

for train_index, val_index in kf.split(x_train):
    x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    print(f"Traitement du pli {fold}/{n_folds}")
    datagen = ImageDataGenerator(zoom_range=0.1, shear_range=0.1)
    datagen.fit(x_train_fold)
    
    model = create_model()
    
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.0001)
    early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    
    history = model.fit(datagen.flow(x_train_fold, y_train_fold, batch_size=batch_size),
                        epochs=epochs,
                        validation_data=(x_val_fold, y_val_fold),
                        callbacks=[reduce_lr, early_stop])
    
    # Évaluation du pli
    scores = model.evaluate(x_val_fold, y_val_fold, verbose=0)
    print(f"Précision de validation pour le pli {fold}: {scores[1]*100:.2f}%")
    fold_accuracies.append(scores[1])
# Out:
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 206ms/step - accuracy: 0.5082 - loss: 0.6900 - val_accuracy: 0.5000 - val_loss: 0.6819 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.5061 - loss: 0.6885 - val_accuracy: 0.5000 - val_loss: 0.6742 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.5005 - loss: 0.6797 - val_accuracy: 0.5000 - val_loss: 0.6620 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.5586 - loss: 0.6600 - val_accuracy: 0.5000 - val_loss: 0.6420 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.5937 - loss: 0.6454 - val_accuracy: 0.7000 - val_loss: 0.6116 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.7114 - loss: 0.6248 - val_accuracy: 0.7000 - val_loss: 0.5698 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8134 - loss: 0.5883 - val_accuracy: 0.9000 - val_loss: 0.4937 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8554 - loss: 0.5235 - val_accuracy: 0.8500 - val_loss: 0.4127 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8135 - loss: 0.4784 - val_accuracy: 1.0000 - val_loss: 0.3009 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8691 - loss: 0.3942 - val_accuracy: 0.7500 - val_loss: 0.3848 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8652 - loss: 0.3569 - val_accuracy: 0.9000 - val_loss: 0.2539 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8947 - loss: 0.3954 - val_accuracy: 1.0000 - val_loss: 0.1878 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8102 - loss: 0.4050 - val_accuracy: 0.9000 - val_loss: 0.1925 - learning_rate: 0.0010
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9077 - loss: 0.2724 - val_accuracy: 0.9000 - val_loss: 0.2056 - learning_rate: 0.0010
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8784 - loss: 0.3247 - val_accuracy: 1.0000 - val_loss: 0.1611 - learning_rate: 0.0010
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8756 - loss: 0.3179 - val_accuracy: 0.9000 - val_loss: 0.1996 - learning_rate: 0.0010
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9339 - loss: 0.2758 - val_accuracy: 1.0000 - val_loss: 0.1222 - learning_rate: 0.0010
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8825 - loss: 0.2847 - val_accuracy: 0.9500 - val_loss: 0.1394 - learning_rate: 0.0010
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9106 - loss: 0.2696 - val_accuracy: 1.0000 - val_loss: 0.1029 - learning_rate: 0.0010
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9094 - loss: 0.2498 - val_accuracy: 0.9500 - val_loss: 0.1105 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 100.00%
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - accuracy: 0.5995 - loss: 0.6869 - val_accuracy: 0.4500 - val_loss: 0.6649 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5233 - loss: 0.6593 - val_accuracy: 0.4500 - val_loss: 0.6420 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.5128 - loss: 0.6231 - val_accuracy: 0.5000 - val_loss: 0.6056 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.6411 - loss: 0.5988 - val_accuracy: 0.7500 - val_loss: 0.5564 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7580 - loss: 0.5586 - val_accuracy: 0.7500 - val_loss: 0.5056 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8141 - loss: 0.4957 - val_accuracy: 0.8500 - val_loss: 0.4265 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.8391 - loss: 0.4473 - val_accuracy: 0.8500 - val_loss: 0.3674 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8650 - loss: 0.3752 - val_accuracy: 0.8000 - val_loss: 0.4056 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8759 - loss: 0.3160 - val_accuracy: 0.8500 - val_loss: 0.2859 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9330 - loss: 0.2448 - val_accuracy: 0.8500 - val_loss: 0.2783 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8673 - loss: 0.3610 - val_accuracy: 0.8500 - val_loss: 0.2444 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9254 - loss: 0.2428 - val_accuracy: 0.8500 - val_loss: 0.2384 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9141 - loss: 0.2443 - val_accuracy: 0.8500 - val_loss: 0.2763 - learning_rate: 0.0010
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9254 - loss: 0.2163 - val_accuracy: 0.8500 - val_loss: 0.2070 - learning_rate: 0.0010
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9317 - loss: 0.2298 - val_accuracy: 0.8500 - val_loss: 0.1967 - learning_rate: 0.0010
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9073 - loss: 0.2070 - val_accuracy: 0.9000 - val_loss: 0.2336 - learning_rate: 0.0010
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9048 - loss: 0.2525 - val_accuracy: 0.9000 - val_loss: 0.2087 - learning_rate: 0.0010
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9101 - loss: 0.1985 - val_accuracy: 0.9000 - val_loss: 0.1856 - learning_rate: 0.0010
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9574 - loss: 0.1481 - val_accuracy: 0.9000 - val_loss: 0.1863 - learning_rate: 0.0010
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9655 - loss: 0.1504 - val_accuracy: 0.9500 - val_loss: 0.1618 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 95.00%
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - accuracy: 0.6204 - loss: 0.6917 - val_accuracy: 0.5000 - val_loss: 0.6802 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.5103 - loss: 0.6818 - val_accuracy: 0.5000 - val_loss: 0.6598 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5719 - loss: 0.6657 - val_accuracy: 0.6000 - val_loss: 0.6310 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.7039 - loss: 0.6414 - val_accuracy: 0.6000 - val_loss: 0.5925 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.7182 - loss: 0.6048 - val_accuracy: 0.7500 - val_loss: 0.5369 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8467 - loss: 0.5646 - val_accuracy: 0.8000 - val_loss: 0.4652 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9083 - loss: 0.4798 - val_accuracy: 0.9000 - val_loss: 0.3997 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8957 - loss: 0.4126 - val_accuracy: 0.9500 - val_loss: 0.3202 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8850 - loss: 0.3740 - val_accuracy: 0.9500 - val_loss: 0.3357 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9351 - loss: 0.3068 - val_accuracy: 0.9500 - val_loss: 0.2888 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9046 - loss: 0.3343 - val_accuracy: 0.9500 - val_loss: 0.2735 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8743 - loss: 0.3103 - val_accuracy: 0.8500 - val_loss: 0.4736 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8865 - loss: 0.3505 - val_accuracy: 0.9500 - val_loss: 0.3004 - learning_rate: 0.0010
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9043 - loss: 0.2773 - val_accuracy: 0.9500 - val_loss: 0.3725 - learning_rate: 0.0010
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9508 - loss: 0.2130 - val_accuracy: 0.9500 - val_loss: 0.2852 - learning_rate: 5.0000e-04
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9017 - loss: 0.2419 - val_accuracy: 0.9500 - val_loss: 0.3255 - learning_rate: 5.0000e-04
# Précision de validation pour le pli 1: 95.00%
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.5353 - loss: 0.6831 - val_accuracy: 0.5500 - val_loss: 0.6765 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5929 - loss: 0.6717 - val_accuracy: 0.7000 - val_loss: 0.6806 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.5522 - loss: 0.6808 - val_accuracy: 0.5500 - val_loss: 0.6698 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.5386 - loss: 0.6797 - val_accuracy: 0.5500 - val_loss: 0.6529 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.5684 - loss: 0.6645 - val_accuracy: 0.5500 - val_loss: 0.6398 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.6508 - loss: 0.6488 - val_accuracy: 0.5500 - val_loss: 0.6163 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.7294 - loss: 0.6061 - val_accuracy: 0.9000 - val_loss: 0.5772 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.7032 - loss: 0.5881 - val_accuracy: 0.7000 - val_loss: 0.5816 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7848 - loss: 0.5579 - val_accuracy: 0.9000 - val_loss: 0.4997 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8081 - loss: 0.5239 - val_accuracy: 0.9500 - val_loss: 0.4503 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8514 - loss: 0.4604 - val_accuracy: 0.9000 - val_loss: 0.4054 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8600 - loss: 0.3929 - val_accuracy: 0.9500 - val_loss: 0.3602 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8506 - loss: 0.4088 - val_accuracy: 0.9500 - val_loss: 0.3375 - learning_rate: 0.0010
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8547 - loss: 0.3720 - val_accuracy: 0.9000 - val_loss: 0.3196 - learning_rate: 0.0010
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9031 - loss: 0.3143 - val_accuracy: 0.6000 - val_loss: 0.5843 - learning_rate: 0.0010
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.7372 - loss: 0.5373 - val_accuracy: 0.9500 - val_loss: 0.3145 - learning_rate: 0.0010
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9062 - loss: 0.2960 - val_accuracy: 0.9500 - val_loss: 0.2714 - learning_rate: 0.0010
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9169 - loss: 0.2930 - val_accuracy: 0.8500 - val_loss: 0.3574 - learning_rate: 0.0010
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8397 - loss: 0.3448 - val_accuracy: 0.9500 - val_loss: 0.3277 - learning_rate: 0.0010
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8634 - loss: 0.3040 - val_accuracy: 0.9000 - val_loss: 0.2619 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 90.00%
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 186ms/step - accuracy: 0.4863 - loss: 0.7098 - val_accuracy: 0.4500 - val_loss: 0.6928 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5575 - loss: 0.6914 - val_accuracy: 0.8000 - val_loss: 0.6621 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.5506 - loss: 0.6881 - val_accuracy: 0.9000 - val_loss: 0.6446 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5815 - loss: 0.6576 - val_accuracy: 0.6500 - val_loss: 0.6324 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.6459 - loss: 0.6365 - val_accuracy: 0.7500 - val_loss: 0.6000 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.6484 - loss: 0.6327 - val_accuracy: 0.9000 - val_loss: 0.5309 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.7103 - loss: 0.6045 - val_accuracy: 0.9000 - val_loss: 0.4669 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.7316 - loss: 0.5607 - val_accuracy: 0.8500 - val_loss: 0.4232 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.7944 - loss: 0.4726 - val_accuracy: 0.9500 - val_loss: 0.3297 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.7861 - loss: 0.4932 - val_accuracy: 0.8000 - val_loss: 0.4701 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.7645 - loss: 0.5036 - val_accuracy: 0.8000 - val_loss: 0.3608 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7185 - loss: 0.5016 - val_accuracy: 0.8500 - val_loss: 0.3318 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8917 - loss: 0.3577 - val_accuracy: 0.9500 - val_loss: 0.2329 - learning_rate: 5.0000e-04
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8778 - loss: 0.3503 - val_accuracy: 0.9500 - val_loss: 0.2112 - learning_rate: 5.0000e-04
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8717 - loss: 0.3552 - val_accuracy: 0.8500 - val_loss: 0.2546 - learning_rate: 5.0000e-04
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8217 - loss: 0.3587 - val_accuracy: 0.9500 - val_loss: 0.1876 - learning_rate: 5.0000e-04
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8703 - loss: 0.3429 - val_accuracy: 0.9500 - val_loss: 0.2064 - learning_rate: 5.0000e-04
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8544 - loss: 0.3256 - val_accuracy: 0.9500 - val_loss: 0.1870 - learning_rate: 5.0000e-04
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9000 - loss: 0.2951 - val_accuracy: 0.9500 - val_loss: 0.1814 - learning_rate: 5.0000e-04
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8826 - loss: 0.2626 - val_accuracy: 0.9500 - val_loss: 0.1845 - learning_rate: 5.0000e-04
# Précision de validation pour le pli 1: 95.00%
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 341ms/step - accuracy: 0.4299 - loss: 0.6936 - val_accuracy: 0.5500 - val_loss: 0.6868 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5087 - loss: 0.6854 - val_accuracy: 0.5500 - val_loss: 0.6739 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.4963 - loss: 0.6752 - val_accuracy: 0.5500 - val_loss: 0.6486 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.5011 - loss: 0.6367 - val_accuracy: 0.5500 - val_loss: 0.6228 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.6097 - loss: 0.5865 - val_accuracy: 0.7500 - val_loss: 0.5731 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8337 - loss: 0.5369 - val_accuracy: 0.7500 - val_loss: 0.5083 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8384 - loss: 0.4621 - val_accuracy: 0.8500 - val_loss: 0.4199 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8436 - loss: 0.4099 - val_accuracy: 0.7500 - val_loss: 0.4911 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8861 - loss: 0.3633 - val_accuracy: 0.9000 - val_loss: 0.3239 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8578 - loss: 0.3243 - val_accuracy: 0.8500 - val_loss: 0.3945 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8899 - loss: 0.2845 - val_accuracy: 0.8500 - val_loss: 0.3957 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8717 - loss: 0.3814 - val_accuracy: 0.7500 - val_loss: 0.3468 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8451 - loss: 0.3197 - val_accuracy: 0.8500 - val_loss: 0.3938 - learning_rate: 5.0000e-04
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8917 - loss: 0.2981 - val_accuracy: 0.9000 - val_loss: 0.3094 - learning_rate: 5.0000e-04
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8884 - loss: 0.2651 - val_accuracy: 0.9000 - val_loss: 0.2773 - learning_rate: 5.0000e-04
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9167 - loss: 0.2562 - val_accuracy: 0.9000 - val_loss: 0.3500 - learning_rate: 5.0000e-04
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8974 - loss: 0.2939 - val_accuracy: 0.9000 - val_loss: 0.2843 - learning_rate: 5.0000e-04
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9232 - loss: 0.1883 - val_accuracy: 0.9000 - val_loss: 0.3294 - learning_rate: 5.0000e-04
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9439 - loss: 0.1984 - val_accuracy: 0.9000 - val_loss: 0.3016 - learning_rate: 2.5000e-04
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9104 - loss: 0.2486 - val_accuracy: 0.9000 - val_loss: 0.2627 - learning_rate: 2.5000e-04
# Précision de validation pour le pli 1: 90.00%
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - accuracy: 0.6069 - loss: 0.6872 - val_accuracy: 0.5000 - val_loss: 0.6856 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5225 - loss: 0.7012 - val_accuracy: 0.6500 - val_loss: 0.6785 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.5907 - loss: 0.6761 - val_accuracy: 0.6000 - val_loss: 0.6704 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6503 - loss: 0.6674 - val_accuracy: 0.8000 - val_loss: 0.6621 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.6171 - loss: 0.6566 - val_accuracy: 0.7000 - val_loss: 0.6512 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6879 - loss: 0.6443 - val_accuracy: 0.7500 - val_loss: 0.6328 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.7117 - loss: 0.6166 - val_accuracy: 0.8000 - val_loss: 0.6057 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8529 - loss: 0.5745 - val_accuracy: 0.8000 - val_loss: 0.5719 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8059 - loss: 0.5314 - val_accuracy: 0.8000 - val_loss: 0.5369 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.8581 - loss: 0.4742 - val_accuracy: 0.8500 - val_loss: 0.5053 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8707 - loss: 0.4026 - val_accuracy: 0.8500 - val_loss: 0.4843 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8778 - loss: 0.3548 - val_accuracy: 0.7500 - val_loss: 0.5026 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8428 - loss: 0.3675 - val_accuracy: 0.7500 - val_loss: 0.5136 - learning_rate: 0.0010
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9041 - loss: 0.2652 - val_accuracy: 0.8500 - val_loss: 0.4277 - learning_rate: 0.0010
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8741 - loss: 0.3040 - val_accuracy: 0.8000 - val_loss: 0.5025 - learning_rate: 0.0010
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9020 - loss: 0.2687 - val_accuracy: 0.7500 - val_loss: 0.4124 - learning_rate: 0.0010
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8647 - loss: 0.3280 - val_accuracy: 0.8000 - val_loss: 0.4045 - learning_rate: 0.0010
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8450 - loss: 0.2782 - val_accuracy: 0.8500 - val_loss: 0.4457 - learning_rate: 0.0010
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9273 - loss: 0.2342 - val_accuracy: 0.8000 - val_loss: 0.4022 - learning_rate: 0.0010
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9175 - loss: 0.2574 - val_accuracy: 0.8000 - val_loss: 0.4908 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 80.00%
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.5239 - loss: 0.6886 - val_accuracy: 0.4000 - val_loss: 0.7004 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.5123 - loss: 0.6884 - val_accuracy: 0.4000 - val_loss: 0.6970 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.6238 - loss: 0.6642 - val_accuracy: 0.4000 - val_loss: 0.6843 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5972 - loss: 0.6543 - val_accuracy: 0.7000 - val_loss: 0.6533 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6038 - loss: 0.6486 - val_accuracy: 0.9000 - val_loss: 0.6062 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6523 - loss: 0.6128 - val_accuracy: 0.4500 - val_loss: 0.6720 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6325 - loss: 0.5912 - val_accuracy: 0.9000 - val_loss: 0.5141 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8430 - loss: 0.4933 - val_accuracy: 0.8500 - val_loss: 0.5242 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8141 - loss: 0.4564 - val_accuracy: 0.8500 - val_loss: 0.4713 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.8446 - loss: 0.4230 - val_accuracy: 0.7500 - val_loss: 0.4114 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8600 - loss: 0.3805 - val_accuracy: 0.8500 - val_loss: 0.4943 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9186 - loss: 0.2991 - val_accuracy: 0.8500 - val_loss: 0.5414 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8533 - loss: 0.3559 - val_accuracy: 0.9000 - val_loss: 0.3804 - learning_rate: 0.0010
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9035 - loss: 0.2805 - val_accuracy: 0.9000 - val_loss: 0.3763 - learning_rate: 0.0010
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9001 - loss: 0.3199 - val_accuracy: 0.9000 - val_loss: 0.3770 - learning_rate: 0.0010
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8932 - loss: 0.2723 - val_accuracy: 0.9000 - val_loss: 0.3590 - learning_rate: 0.0010
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9279 - loss: 0.2417 - val_accuracy: 0.9000 - val_loss: 0.3085 - learning_rate: 0.0010
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8653 - loss: 0.2900 - val_accuracy: 0.8500 - val_loss: 0.4955 - learning_rate: 0.0010
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9207 - loss: 0.2689 - val_accuracy: 0.9000 - val_loss: 0.3014 - learning_rate: 0.0010
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9519 - loss: 0.1745 - val_accuracy: 0.8500 - val_loss: 0.4410 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 90.00%
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.5314 - loss: 0.6906 - val_accuracy: 0.5500 - val_loss: 0.6721 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5283 - loss: 0.6800 - val_accuracy: 0.6000 - val_loss: 0.6506 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.5894 - loss: 0.6652 - val_accuracy: 0.6500 - val_loss: 0.6181 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6450 - loss: 0.6333 - val_accuracy: 0.6500 - val_loss: 0.5771 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.7915 - loss: 0.6052 - val_accuracy: 0.7500 - val_loss: 0.5354 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.7743 - loss: 0.5820 - val_accuracy: 0.8000 - val_loss: 0.4905 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.8032 - loss: 0.5404 - val_accuracy: 0.7500 - val_loss: 0.4639 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8684 - loss: 0.4609 - val_accuracy: 0.7500 - val_loss: 0.4173 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9054 - loss: 0.4155 - val_accuracy: 0.7000 - val_loss: 0.4708 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9179 - loss: 0.3663 - val_accuracy: 0.7500 - val_loss: 0.3922 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8913 - loss: 0.3440 - val_accuracy: 0.7500 - val_loss: 0.4847 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9036 - loss: 0.3134 - val_accuracy: 0.8500 - val_loss: 0.3190 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9042 - loss: 0.2802 - val_accuracy: 0.9000 - val_loss: 0.2427 - learning_rate: 0.0010
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8601 - loss: 0.3486 - val_accuracy: 0.7500 - val_loss: 0.4246 - learning_rate: 0.0010
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8427 - loss: 0.3332 - val_accuracy: 0.7500 - val_loss: 0.4889 - learning_rate: 0.0010
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9125 - loss: 0.3094 - val_accuracy: 0.8000 - val_loss: 0.3536 - learning_rate: 0.0010
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9390 - loss: 0.2926 - val_accuracy: 0.7500 - val_loss: 0.3817 - learning_rate: 5.0000e-04
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9378 - loss: 0.2493 - val_accuracy: 0.8500 - val_loss: 0.3392 - learning_rate: 5.0000e-04
# Précision de validation pour le pli 1: 90.00%
# Traitement du pli 1/10
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 168ms/step - accuracy: 0.5076 - loss: 0.6932 - val_accuracy: 0.5500 - val_loss: 0.6892 - learning_rate: 0.0010
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.5006 - loss: 0.6907 - val_accuracy: 0.5000 - val_loss: 0.6828 - learning_rate: 0.0010
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5765 - loss: 0.6858 - val_accuracy: 0.5500 - val_loss: 0.6646 - learning_rate: 0.0010
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5744 - loss: 0.6787 - val_accuracy: 0.6000 - val_loss: 0.6253 - learning_rate: 0.0010
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.6442 - loss: 0.6411 - val_accuracy: 0.6500 - val_loss: 0.5495 - learning_rate: 0.0010
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6800 - loss: 0.6078 - val_accuracy: 0.8000 - val_loss: 0.4791 - learning_rate: 0.0010
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8371 - loss: 0.5184 - val_accuracy: 0.8500 - val_loss: 0.3952 - learning_rate: 0.0010
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.8784 - loss: 0.4315 - val_accuracy: 0.9000 - val_loss: 0.2868 - learning_rate: 0.0010
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8372 - loss: 0.4053 - val_accuracy: 0.9000 - val_loss: 0.2151 - learning_rate: 0.0010
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9076 - loss: 0.2921 - val_accuracy: 0.9500 - val_loss: 0.2638 - learning_rate: 0.0010
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8527 - loss: 0.3898 - val_accuracy: 0.9000 - val_loss: 0.2018 - learning_rate: 0.0010
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8595 - loss: 0.3403 - val_accuracy: 0.9500 - val_loss: 0.1806 - learning_rate: 0.0010
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8942 - loss: 0.2795 - val_accuracy: 0.9500 - val_loss: 0.1344 - learning_rate: 0.0010
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9116 - loss: 0.2523 - val_accuracy: 0.9500 - val_loss: 0.1178 - learning_rate: 0.0010
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.8990 - loss: 0.2467 - val_accuracy: 0.9500 - val_loss: 0.1497 - learning_rate: 0.0010
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9235 - loss: 0.2229 - val_accuracy: 0.9000 - val_loss: 0.1493 - learning_rate: 0.0010
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8979 - loss: 0.1939 - val_accuracy: 1.0000 - val_loss: 0.1030 - learning_rate: 0.0010
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8945 - loss: 0.2106 - val_accuracy: 0.9500 - val_loss: 0.1069 - learning_rate: 0.0010
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9473 - loss: 0.1527 - val_accuracy: 0.9500 - val_loss: 0.1052 - learning_rate: 0.0010
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9099 - loss: 0.2371 - val_accuracy: 0.9500 - val_loss: 0.1535 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 100.00%

# %%
def plot_learning_curves(history):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Perte d\'entraînement')
    plt.plot(history.history['val_loss'], label='Perte de validation')
    plt.xlabel('Époques')
    plt.ylabel('Perte')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Précision d\'entraînement')
    plt.plot(history.history['val_accuracy'], label='Précision de validation')
    plt.xlabel('Époques')
    plt.ylabel('Précision')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_learning_curves(history)

# %%
def matrice_de_confusion():
    y_pred = (model.predict(x_val_fold) > 0.5).astype("int32")
    cm = confusion_matrix(y_val_fold, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['PNEUMONIA', 'NORMAL'], yticklabels=['PNEUMONIA', 'NORMAL'])
    plt.ylabel('Réel')
    plt.xlabel('Prévu')
    plt.title(f'Matrice de confusion pour le pli {fold}')
    plt.show()

matrice_de_confusion()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step

# %%
def roc():
    fpr, tpr, _ = roc_curve(y_val_fold, (model.predict(x_val_fold) > 0.5).astype("int32"))
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Courbe ROC (aire = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('Taux de Faux Positifs')
    plt.ylabel('Taux de Vrais Positifs')
    plt.title(f'Courbe ROC pour le pli {fold}')
    plt.legend(loc='lower right')
    plt.show()

    fold += 1
    print(f"Précision moyenne sur les {n_folds} plis : {np.mean(fold_accuracies)*100:.2f}%")

roc()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[74], line 16
#      13     fold += 1
#      14     print(f"Précision moyenne sur les {n_folds} plis : {np.mean(fold_accuracies)*100:.2f}%")
# ---> 16 roc()
#
# Cell In[74], line 9, in roc()
#       7 plt.xlabel('Taux de Faux Positifs')
#       8 plt.ylabel('Taux de Vrais Positifs')
# ----> 9 plt.title(f'Courbe ROC pour le pli {fold}')
#      10 plt.legend(loc='lower right')
#      11 plt.show()
#
# UnboundLocalError: cannot access local variable 'fold' where it is not associated with a value

# %%
print("Entraînement du modèle final sur l'ensemble des données...")
datagen_final = ImageDataGenerator(zoom_range=0.1, shear_range=0.1)
datagen_final.fit(x_train)
model_final = create_model()
history_final = model_final.fit(datagen_final.flow(x_train, y_train, batch_size=batch_size),
                                epochs=epochs,
                                validation_data=(x_train, y_train),
                                callbacks=[reduce_lr, early_stop])
# Out:
# Entraînement du modèle final sur l'ensemble des données...
# Définition du modèle...
# Modèle défini.
# Modèle compilé
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.5308 - loss: 0.6941 - val_accuracy: 0.5000 - val_loss: 0.6912 - learning_rate: 0.0010
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.5302 - loss: 0.6870 - val_accuracy: 0.5000 - val_loss: 0.6831 - learning_rate: 0.0010
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.5689 - loss: 0.6807 - val_accuracy: 0.5000 - val_loss: 0.6765 - learning_rate: 0.0010
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5152 - loss: 0.6788 - val_accuracy: 0.5000 - val_loss: 0.6702 - learning_rate: 0.0010
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.5142 - loss: 0.6693 - val_accuracy: 0.5000 - val_loss: 0.6601 - learning_rate: 0.0010

# %%
# Évaluation du modèle final
scores_final = model_final.evaluate(x_train, y_train, verbose=0)
print(f"Précision du modèle final: {scores_final[1]*100:.2f}%")
print(f"Perte du modèle final: {scores_final[0]:.4f}")
# Out:
# Précision du modèle final: 50.00%
# Perte du modèle final: 0.6912

# %%
plot_learning_curves(history_final)

# %%
def matrice_de_confusion2():
    y_pred_final = (model_final.predict(x_train) > 0.5).astype("int32")
    cm_final = confusion_matrix(y_train, y_pred_final)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_final, annot=True, fmt='d', cmap='Blues', xticklabels=['PNEUMONIA', 'NORMAL'], yticklabels=['PNEUMONIA', 'NORMAL'])
    plt.ylabel('Réel')
    plt.xlabel('Prévu')
    plt.title('Matrice de confusion pour le modèle final')
    plt.show()
    print(f"Matrice de confusion pour le modèle final:\n", cm_final)
    cr_final = classification_report(y_train, y_pred_final, target_names=['PNEUMONIA', 'NORMAL'])
    print(f"Rapport de classification pour le modèle final:\n", cr_final)

matrice_de_confusion2()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# Matrice de confusion pour le modèle final:
#  [[  0 100]
#  [  0 100]]
# Rapport de classification pour le modèle final:
#                precision    recall  f1-score   support
#
#    PNEUMONIA       0.00      0.00      0.00       100
#       NORMAL       0.50      1.00      0.67       100
#
#     accuracy                           0.50       200
#    macro avg       0.25      0.50      0.33       200
# weighted avg       0.25      0.50      0.33       200
# C:\Users\vikne\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\vikne\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\vikne\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
def roc2():
    # Courbe ROC pour le modèle final
    fpr_final, tpr_final, _ = roc_curve(y_train, (model_final.predict(x_train) > 0.5).astype("int32"))
    roc_auc_final = auc(fpr_final, tpr_final)
    plt.figure()
    plt.plot(fpr_final, tpr_final, color='darkorange', lw=2, label=f'Courbe ROC (aire = {roc_auc_final:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Taux de Faux Positifs')
    plt.ylabel('Taux de Vrais Positifs')
    plt.title('Courbe ROC pour le modèle final')
    plt.legend(loc='lower right')
    plt.show()

roc2()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
# Fonction pour afficher les prédictions
def display_predictions_simple(model, x_data, y_data, num_images=5):
    print("Affichage des prédictions simples...")
    predictions = (model.predict(x_data) > 0.5).astype("int32")
    plt.figure(figsize=(12, 6))
    for i in range(num_images):
        plt.subplot(1, num_images, i+1)
        plt.imshow(x_data[i].astype(np.uint8))
        plt.title(f"Vrai: {['PNEUMONIA', 'NORMAL'][y_data[i]]}\nPréd: {['PNEUMONIA', 'NORMAL'][predictions[i][0]]}")
        plt.axis('off')
    plt.show()

display_predictions_simple(model_final, x_train, y_train)
# Out:
# Affichage des prédictions simples...
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
# Fonction pour afficher l'histogramme des prédictions
def plot_prediction_histogram(model, x_data, bins=20):
    print("Affichage de l'histogramme des prédictions...")
    predictions = model.predict(x_data)
    plt.hist(predictions, bins=bins, edgecolor='black')
    plt.xlabel('Probabilités prédites')
    plt.ylabel('Nombre d\'échantillons')
    plt.title('Histogramme des probabilités prédites')
    plt.show()

plot_prediction_histogram(model_final, x_train)
# Out:
# Affichage de l'histogramme des prédictions...
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
