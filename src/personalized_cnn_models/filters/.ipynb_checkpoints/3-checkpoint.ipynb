# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns
import time

# %%
print("Vérification GPU...")
if tf.config.list_physical_devices('GPU'):
    print("GPU détecté.")
else:
    print("Aucun GPU détecté, l'entraînement se fera sur le CPU.")
# Out:
# Vérification GPU...
# Aucun GPU détecté, l'entraînement se fera sur le CPU.

# %%
img_size = 128
batch_size = 32
epochs = 10
n_folds = 10
filter_numbers = [128, 256, 512, 1024]
data_dir1 = '../../../chest_xray/train/PNEUMONIA'
data_dir2 = '../../../chest_xray/train/NORMAL'

# %%
def load_data(data_dir1, data_dir2, limit=100):
    print("Chargement des données...")
    data = []
    labels = ['PNEUMONIA', 'NORMAL']
    for dir in [data_dir1, data_dir2]:
        path = os.path.join(dir)
        if not os.path.exists(path):
            print(f"Le répertoire {path} n'existe pas")
            continue
        label = os.path.basename(dir)
        class_num = labels.index(label)
        for i, img in enumerate(os.listdir(path)):
            if i >= limit:
                break
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                if img_arr is None:
                    print(f"Échec de la lecture de {img}. Passage au suivant.")
                    continue
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    print("Chargement des données terminé.")
    return np.array(data, dtype=object)

train_data = load_data(data_dir1, data_dir2, limit=100)
# Out:
# Chargement des données...
# Chargement des données terminé.

# %%
# Prétraitement des images
def preprocess_image(image):
    if len(image.shape) == 2:
        image = np.expand_dims(image, axis=-1)
    image = tf.image.resize(image, [img_size, img_size])
    image = image / 255.0  # Normalisation
    return image

# Prétraitement des données
def preprocess_data(data):
    print("Prétraitement des données...")
    processed_data = []
    for idx, (img, label) in enumerate(data):
        print(f"Traitement de l'image {idx+1}/{len(data)}")
        img = preprocess_image(img)
        processed_data.append([img, label])
    return np.array(processed_data, dtype=object)

train_data = preprocess_data(train_data)
# Out:
# Prétraitement des données...
# Traitement de l'image 1/200
# Traitement de l'image 2/200
# Traitement de l'image 3/200
# Traitement de l'image 4/200
# Traitement de l'image 5/200
# Traitement de l'image 6/200
# Traitement de l'image 7/200
# Traitement de l'image 8/200
# Traitement de l'image 9/200
# Traitement de l'image 10/200
# Traitement de l'image 11/200
# Traitement de l'image 12/200
# Traitement de l'image 13/200
# Traitement de l'image 14/200
# Traitement de l'image 15/200
# Traitement de l'image 16/200
# Traitement de l'image 17/200
# Traitement de l'image 18/200
# Traitement de l'image 19/200
# Traitement de l'image 20/200
# Traitement de l'image 21/200
# Traitement de l'image 22/200
# Traitement de l'image 23/200
# Traitement de l'image 24/200
# Traitement de l'image 25/200
# Traitement de l'image 26/200
# Traitement de l'image 27/200
# Traitement de l'image 28/200
# Traitement de l'image 29/200
# Traitement de l'image 30/200
# Traitement de l'image 31/200
# Traitement de l'image 32/200
# Traitement de l'image 33/200
# Traitement de l'image 34/200
# Traitement de l'image 35/200
# Traitement de l'image 36/200
# Traitement de l'image 37/200
# Traitement de l'image 38/200
# Traitement de l'image 39/200
# Traitement de l'image 40/200
# Traitement de l'image 41/200
# Traitement de l'image 42/200
# Traitement de l'image 43/200
# Traitement de l'image 44/200
# Traitement de l'image 45/200
# Traitement de l'image 46/200
# Traitement de l'image 47/200
# Traitement de l'image 48/200
# Traitement de l'image 49/200
# Traitement de l'image 50/200
# Traitement de l'image 51/200
# Traitement de l'image 52/200
# Traitement de l'image 53/200
# Traitement de l'image 54/200
# Traitement de l'image 55/200
# Traitement de l'image 56/200
# Traitement de l'image 57/200
# Traitement de l'image 58/200
# Traitement de l'image 59/200
# Traitement de l'image 60/200
# Traitement de l'image 61/200
# Traitement de l'image 62/200
# Traitement de l'image 63/200
# Traitement de l'image 64/200
# Traitement de l'image 65/200
# Traitement de l'image 66/200
# Traitement de l'image 67/200
# Traitement de l'image 68/200
# Traitement de l'image 69/200
# Traitement de l'image 70/200
# Traitement de l'image 71/200
# Traitement de l'image 72/200
# Traitement de l'image 73/200
# Traitement de l'image 74/200
# Traitement de l'image 75/200
# Traitement de l'image 76/200
# Traitement de l'image 77/200
# Traitement de l'image 78/200
# Traitement de l'image 79/200
# Traitement de l'image 80/200
# Traitement de l'image 81/200
# Traitement de l'image 82/200
# Traitement de l'image 83/200
# Traitement de l'image 84/200
# Traitement de l'image 85/200
# Traitement de l'image 86/200
# Traitement de l'image 87/200
# Traitement de l'image 88/200
# Traitement de l'image 89/200
# Traitement de l'image 90/200
# Traitement de l'image 91/200
# Traitement de l'image 92/200
# Traitement de l'image 93/200
# Traitement de l'image 94/200
# Traitement de l'image 95/200
# Traitement de l'image 96/200
# Traitement de l'image 97/200
# Traitement de l'image 98/200
# Traitement de l'image 99/200
# Traitement de l'image 100/200
# Traitement de l'image 101/200
# Traitement de l'image 102/200
# Traitement de l'image 103/200
# Traitement de l'image 104/200
# Traitement de l'image 105/200
# Traitement de l'image 106/200
# Traitement de l'image 107/200
# Traitement de l'image 108/200
# Traitement de l'image 109/200
# Traitement de l'image 110/200
# Traitement de l'image 111/200
# Traitement de l'image 112/200
# Traitement de l'image 113/200
# Traitement de l'image 114/200
# Traitement de l'image 115/200
# Traitement de l'image 116/200
# Traitement de l'image 117/200
# Traitement de l'image 118/200
# Traitement de l'image 119/200
# Traitement de l'image 120/200
# Traitement de l'image 121/200
# Traitement de l'image 122/200
# Traitement de l'image 123/200
# Traitement de l'image 124/200
# Traitement de l'image 125/200
# Traitement de l'image 126/200
# Traitement de l'image 127/200
# Traitement de l'image 128/200
# Traitement de l'image 129/200
# Traitement de l'image 130/200
# Traitement de l'image 131/200
# Traitement de l'image 132/200
# Traitement de l'image 133/200
# Traitement de l'image 134/200
# Traitement de l'image 135/200
# Traitement de l'image 136/200
# Traitement de l'image 137/200
# Traitement de l'image 138/200
# Traitement de l'image 139/200
# Traitement de l'image 140/200
# Traitement de l'image 141/200
# Traitement de l'image 142/200
# Traitement de l'image 143/200
# Traitement de l'image 144/200
# Traitement de l'image 145/200
# Traitement de l'image 146/200
# Traitement de l'image 147/200
# Traitement de l'image 148/200
# Traitement de l'image 149/200
# Traitement de l'image 150/200
# Traitement de l'image 151/200
# Traitement de l'image 152/200
# Traitement de l'image 153/200
# Traitement de l'image 154/200
# Traitement de l'image 155/200
# Traitement de l'image 156/200
# Traitement de l'image 157/200
# Traitement de l'image 158/200
# Traitement de l'image 159/200
# Traitement de l'image 160/200
# Traitement de l'image 161/200
# Traitement de l'image 162/200
# Traitement de l'image 163/200
# Traitement de l'image 164/200
# Traitement de l'image 165/200
# Traitement de l'image 166/200
# Traitement de l'image 167/200
# Traitement de l'image 168/200
# Traitement de l'image 169/200
# Traitement de l'image 170/200
# Traitement de l'image 171/200
# Traitement de l'image 172/200
# Traitement de l'image 173/200
# Traitement de l'image 174/200
# Traitement de l'image 175/200
# Traitement de l'image 176/200
# Traitement de l'image 177/200
# Traitement de l'image 178/200
# Traitement de l'image 179/200
# Traitement de l'image 180/200
# Traitement de l'image 181/200
# Traitement de l'image 182/200
# Traitement de l'image 183/200
# Traitement de l'image 184/200
# Traitement de l'image 185/200
# Traitement de l'image 186/200
# Traitement de l'image 187/200
# Traitement de l'image 188/200
# Traitement de l'image 189/200
# Traitement de l'image 190/200
# Traitement de l'image 191/200
# Traitement de l'image 192/200
# Traitement de l'image 193/200
# Traitement de l'image 194/200
# Traitement de l'image 195/200
# Traitement de l'image 196/200
# Traitement de l'image 197/200
# Traitement de l'image 198/200
# Traitement de l'image 199/200
# Traitement de l'image 200/200

# %%
def separate_features_labels(data):
    images = np.array([item[0] for item in data])
    labels = np.array([item[1] for item in data])
    return images, labels

x_train, y_train = separate_features_labels(train_data)
x_train = x_train.reshape(-1, img_size, img_size, 1)
x_train = np.concatenate([x_train, x_train, x_train], axis=-1) 

print("finished separating labels")
# Out:
# finished separating labels

# %%
def create_model(n_filters):
    print(f"Définition du modèle avec {n_filters} filtres...")
    model = Sequential([
        Conv2D(n_filters, (3, 3), activation='relu', input_shape=(img_size, img_size, 3)),
        MaxPooling2D((2, 2)),
        Conv2D(n_filters*2, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(n_filters*4, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(n_filters*8, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])
    print("Modèle défini.")
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
                  loss='binary_crossentropy', 
                  metrics=['accuracy'])
    print("Modèle compilé")
    return model

# Validation croisée K-Fold
for n_filters in filter_numbers:
    print(f"Évaluation avec {n_filters} filtres")
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
    fold = 1
    fold_accuracies = []
    training_times = []

    for train_index, val_index in kf.split(x_train):
        x_train_fold, x_val_fold = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

        print(f"Traitement du pli {fold}/{n_folds}")
        datagen = ImageDataGenerator(zoom_range=0.1, shear_range=0.1)
        datagen.fit(x_train_fold)
        
        model = create_model(n_filters)
        
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.0001)
        early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
        
        start_time = time.time()
        history = model.fit(datagen.flow(x_train_fold, y_train_fold, batch_size=batch_size),
                            epochs=epochs,
                            validation_data=(x_val_fold, y_val_fold),
                            callbacks=[reduce_lr, early_stop])
        end_time = time.time()
        
        training_time = end_time - start_time
        training_times.append(training_time)
        
        # Évaluation du pli
        scores = model.evaluate(x_val_fold, y_val_fold, verbose=0)
        print(f"Précision de validation pour le pli {fold}: {scores[1]*100:.2f}%")
        fold_accuracies.append(scores[1])

print("finished creating model")
# Out:
# Évaluation avec 128 filtres
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# C:\Users\vikne\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# C:\Users\vikne\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - accuracy: 0.4549 - loss: 1.0082 - val_accuracy: 0.5000 - val_loss: 0.6943 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.5815 - loss: 0.7282 - val_accuracy: 0.5000 - val_loss: 0.6932 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.5136 - loss: 0.7060 - val_accuracy: 0.5000 - val_loss: 0.6919 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.5037 - loss: 0.6936 - val_accuracy: 0.5000 - val_loss: 0.6913 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.4856 - loss: 0.6927 - val_accuracy: 0.5000 - val_loss: 0.6908 - learning_rate: 0.0010
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.5535 - loss: 0.6905 - val_accuracy: 0.7000 - val_loss: 0.6907 - learning_rate: 0.0010
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.5499 - loss: 0.6895 - val_accuracy: 0.5000 - val_loss: 0.6863 - learning_rate: 0.0010
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.5482 - loss: 0.6813 - val_accuracy: 0.5000 - val_loss: 0.6797 - learning_rate: 0.0010
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 43s 7s/step - accuracy: 0.6344 - loss: 0.6667 - val_accuracy: 0.6500 - val_loss: 0.6503 - learning_rate: 0.0010
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 40s 6s/step - accuracy: 0.6536 - loss: 0.6335 - val_accuracy: 0.7000 - val_loss: 0.5828 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 70.00%
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/step - accuracy: 0.5239 - loss: 2.2055 - val_accuracy: 0.4500 - val_loss: 0.6964 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - accuracy: 0.4673 - loss: 0.6958 - val_accuracy: 0.4500 - val_loss: 0.6926 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 49s 8s/step - accuracy: 0.5302 - loss: 0.6937 - val_accuracy: 0.4500 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 47s 7s/step - accuracy: 0.5108 - loss: 0.6911 - val_accuracy: 0.4500 - val_loss: 0.6921 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.5185 - loss: 0.6923 - val_accuracy: 0.4500 - val_loss: 0.6886 - learning_rate: 0.0010
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 5s/step - accuracy: 0.5418 - loss: 0.6904 - val_accuracy: 0.4500 - val_loss: 0.6843 - learning_rate: 0.0010
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 32s 5s/step - accuracy: 0.5461 - loss: 0.7145 - val_accuracy: 0.7500 - val_loss: 0.6844 - learning_rate: 0.0010
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.5929 - loss: 0.6897 - val_accuracy: 0.5500 - val_loss: 0.6899 - learning_rate: 0.0010
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.5193 - loss: 0.6926 - val_accuracy: 0.5500 - val_loss: 0.6896 - learning_rate: 0.0010
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.5165 - loss: 0.6915 - val_accuracy: 0.6500 - val_loss: 0.6871 - learning_rate: 5.0000e-04
# Précision de validation pour le pli 1: 45.00%
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - accuracy: 0.4915 - loss: 2.8888 - val_accuracy: 0.5000 - val_loss: 0.6916 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.3901 - loss: 0.7022 - val_accuracy: 0.5000 - val_loss: 0.6916 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 31s 5s/step - accuracy: 0.5248 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6885 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.5317 - loss: 0.6895 - val_accuracy: 0.5000 - val_loss: 0.6839 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.4867 - loss: 0.6964 - val_accuracy: 0.5000 - val_loss: 0.6834 - learning_rate: 0.0010
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.5427 - loss: 0.6898 - val_accuracy: 0.5000 - val_loss: 0.6785 - learning_rate: 0.0010
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.5036 - loss: 0.6884 - val_accuracy: 0.5000 - val_loss: 0.6588 - learning_rate: 0.0010
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.5607 - loss: 0.6865 - val_accuracy: 0.7500 - val_loss: 0.5835 - learning_rate: 0.0010
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.7001 - loss: 0.6229 - val_accuracy: 0.6000 - val_loss: 0.5344 - learning_rate: 0.0010
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.6775 - loss: 0.6093 - val_accuracy: 0.9000 - val_loss: 0.4208 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 90.00%
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 60s 7s/step - accuracy: 0.6033 - loss: 1.2096 - val_accuracy: 0.5500 - val_loss: 0.7154 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 44s 7s/step - accuracy: 0.5272 - loss: 0.6918 - val_accuracy: 0.4500 - val_loss: 0.7140 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 42s 6s/step - accuracy: 0.5336 - loss: 0.6974 - val_accuracy: 0.4500 - val_loss: 0.6947 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.5472 - loss: 0.6888 - val_accuracy: 0.5500 - val_loss: 0.6772 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.5492 - loss: 0.6818 - val_accuracy: 0.5500 - val_loss: 0.6580 - learning_rate: 0.0010
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.5965 - loss: 0.6651 - val_accuracy: 0.5500 - val_loss: 0.6300 - learning_rate: 0.0010
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 40s 6s/step - accuracy: 0.6619 - loss: 0.6257 - val_accuracy: 0.7000 - val_loss: 0.5623 - learning_rate: 0.0010
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - accuracy: 0.7555 - loss: 0.5384 - val_accuracy: 0.7000 - val_loss: 0.4706 - learning_rate: 0.0010
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.8193 - loss: 0.4305 - val_accuracy: 0.9000 - val_loss: 0.2544 - learning_rate: 0.0010
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.9066 - loss: 0.2925 - val_accuracy: 0.6500 - val_loss: 0.5671 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 90.00%
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 54s 7s/step - accuracy: 0.4316 - loss: 1.3654 - val_accuracy: 0.4500 - val_loss: 0.6987 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 39s 6s/step - accuracy: 0.5107 - loss: 0.6941 - val_accuracy: 0.4500 - val_loss: 0.6925 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.5371 - loss: 0.6884 - val_accuracy: 0.4500 - val_loss: 0.6913 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 39s 6s/step - accuracy: 0.5279 - loss: 0.6896 - val_accuracy: 0.4500 - val_loss: 0.6863 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 40s 6s/step - accuracy: 0.5574 - loss: 0.6876 - val_accuracy: 0.5500 - val_loss: 0.6718 - learning_rate: 0.0010
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.5609 - loss: 0.6865 - val_accuracy: 0.8500 - val_loss: 0.6584 - learning_rate: 0.0010
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.7442 - loss: 0.6415 - val_accuracy: 0.9500 - val_loss: 0.4548 - learning_rate: 0.0010
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 50s 8s/step - accuracy: 0.7040 - loss: 0.5566 - val_accuracy: 0.8000 - val_loss: 0.4109 - learning_rate: 0.0010
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 9s/step - accuracy: 0.7638 - loss: 0.5481 - val_accuracy: 0.9000 - val_loss: 0.3500 - learning_rate: 0.0010
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 52s 8s/step - accuracy: 0.8239 - loss: 0.4086 - val_accuracy: 0.9500 - val_loss: 0.1863 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 95.00%
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 75s 10s/step - accuracy: 0.4973 - loss: 0.9229 - val_accuracy: 0.4500 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 52s 8s/step - accuracy: 0.5722 - loss: 0.6922 - val_accuracy: 0.5500 - val_loss: 0.6854 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 56s 9s/step - accuracy: 0.4491 - loss: 0.6971 - val_accuracy: 0.4500 - val_loss: 0.6950 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 56s 9s/step - accuracy: 0.5344 - loss: 0.6909 - val_accuracy: 0.5500 - val_loss: 0.6872 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 51s 9s/step - accuracy: 0.5225 - loss: 0.6942 - val_accuracy: 0.5500 - val_loss: 0.6882 - learning_rate: 0.0010
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 68s 11s/step - accuracy: 0.5011 - loss: 0.6901 - val_accuracy: 0.5500 - val_loss: 0.6837 - learning_rate: 5.0000e-04
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 57s 9s/step - accuracy: 0.5185 - loss: 0.6885 - val_accuracy: 0.5500 - val_loss: 0.6742 - learning_rate: 5.0000e-04
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 56s 9s/step - accuracy: 0.5142 - loss: 0.6780 - val_accuracy: 0.5500 - val_loss: 0.6575 - learning_rate: 5.0000e-04
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 8s/step - accuracy: 0.5597 - loss: 0.6708 - val_accuracy: 0.5500 - val_loss: 0.6423 - learning_rate: 5.0000e-04
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 49s 8s/step - accuracy: 0.5240 - loss: 0.6387 - val_accuracy: 0.7500 - val_loss: 0.6104 - learning_rate: 5.0000e-04
# Précision de validation pour le pli 1: 75.00%
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 66s 9s/step - accuracy: 0.5641 - loss: 1.0569 - val_accuracy: 0.5000 - val_loss: 0.7228 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 48s 7s/step - accuracy: 0.5063 - loss: 0.7124 - val_accuracy: 0.5000 - val_loss: 0.6915 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 55s 9s/step - accuracy: 0.5227 - loss: 0.6916 - val_accuracy: 0.5000 - val_loss: 0.6919 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 49s 7s/step - accuracy: 0.5484 - loss: 0.6893 - val_accuracy: 0.5000 - val_loss: 0.6890 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 8s/step - accuracy: 0.5898 - loss: 0.6706 - val_accuracy: 0.6500 - val_loss: 0.6792 - learning_rate: 0.0010
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 56s 9s/step - accuracy: 0.6536 - loss: 0.6563 - val_accuracy: 0.7000 - val_loss: 0.6541 - learning_rate: 0.0010
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 8s/step - accuracy: 0.7023 - loss: 0.6198 - val_accuracy: 0.6500 - val_loss: 0.7390 - learning_rate: 0.0010
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 50s 8s/step - accuracy: 0.6698 - loss: 0.6111 - val_accuracy: 0.5500 - val_loss: 0.5613 - learning_rate: 0.0010
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 46s 8s/step - accuracy: 0.7971 - loss: 0.5115 - val_accuracy: 0.6500 - val_loss: 0.6934 - learning_rate: 0.0010
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 47s 8s/step - accuracy: 0.7191 - loss: 0.5899 - val_accuracy: 0.7500 - val_loss: 0.5270 - learning_rate: 0.0010
# Précision de validation pour le pli 1: 75.00%
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 61s 7s/step - accuracy: 0.5263 - loss: 1.1248 - val_accuracy: 0.4000 - val_loss: 0.7006 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 48s 8s/step - accuracy: 0.4220 - loss: 0.7059 - val_accuracy: 0.4000 - val_loss: 0.6998 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 52s 8s/step - accuracy: 0.4454 - loss: 0.6967 - val_accuracy: 0.4000 - val_loss: 0.6930 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 55s 8s/step - accuracy: 0.5322 - loss: 0.6937 - val_accuracy: 0.4000 - val_loss: 0.6973 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 47s 8s/step - accuracy: 0.4967 - loss: 0.6928 - val_accuracy: 0.4000 - val_loss: 0.6958 - learning_rate: 0.0010
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 9s/step - accuracy: 0.5209 - loss: 0.6923 - val_accuracy: 0.4000 - val_loss: 0.7000 - learning_rate: 0.0010
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.4847 - loss: 0.6927 - val_accuracy: 0.4000 - val_loss: 0.6994 - learning_rate: 5.0000e-04
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.5241 - loss: 0.6886 - val_accuracy: 0.4000 - val_loss: 0.7123 - learning_rate: 5.0000e-04
# Précision de validation pour le pli 1: 40.00%
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 44s 6s/step - accuracy: 0.4830 - loss: 0.7279 - val_accuracy: 0.5500 - val_loss: 0.6765 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 50s 8s/step - accuracy: 0.4554 - loss: 0.7087 - val_accuracy: 0.5500 - val_loss: 0.6874 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 52s 8s/step - accuracy: 0.5121 - loss: 0.6990 - val_accuracy: 0.4500 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 51s 9s/step - accuracy: 0.5087 - loss: 0.6927 - val_accuracy: 0.8500 - val_loss: 0.6898 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 55s 9s/step - accuracy: 0.5906 - loss: 0.6905 - val_accuracy: 0.5500 - val_loss: 0.6744 - learning_rate: 5.0000e-04
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 65s 10s/step - accuracy: 0.5258 - loss: 0.6782 - val_accuracy: 0.5500 - val_loss: 0.6390 - learning_rate: 5.0000e-04
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 53s 9s/step - accuracy: 0.5447 - loss: 0.6404 - val_accuracy: 0.6500 - val_loss: 0.6171 - learning_rate: 5.0000e-04
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 48s 8s/step - accuracy: 0.7029 - loss: 0.6521 - val_accuracy: 0.7500 - val_loss: 0.5824 - learning_rate: 5.0000e-04
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.7158 - loss: 0.5647 - val_accuracy: 0.7500 - val_loss: 0.4958 - learning_rate: 5.0000e-04
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.8474 - loss: 0.4885 - val_accuracy: 0.6500 - val_loss: 0.7039 - learning_rate: 5.0000e-04
# Précision de validation pour le pli 1: 75.00%
# Traitement du pli 1/10
# Définition du modèle avec 128 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - accuracy: 0.4716 - loss: 1.0355 - val_accuracy: 0.5500 - val_loss: 0.6859 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 33s 6s/step - accuracy: 0.5104 - loss: 0.6996 - val_accuracy: 0.5500 - val_loss: 0.6919 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.5664 - loss: 0.6928 - val_accuracy: 0.5500 - val_loss: 0.6922 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - accuracy: 0.5229 - loss: 0.6925 - val_accuracy: 0.5500 - val_loss: 0.6907 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 6s/step - accuracy: 0.5144 - loss: 0.6919 - val_accuracy: 0.5500 - val_loss: 0.6876 - learning_rate: 5.0000e-04
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step - accuracy: 0.4953 - loss: 0.6911 - val_accuracy: 0.5500 - val_loss: 0.6832 - learning_rate: 5.0000e-04
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.4935 - loss: 0.6891 - val_accuracy: 0.5500 - val_loss: 0.6716 - learning_rate: 5.0000e-04
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.5448 - loss: 0.6805 - val_accuracy: 0.9000 - val_loss: 0.6812 - learning_rate: 5.0000e-04
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step - accuracy: 0.6588 - loss: 0.6809 - val_accuracy: 0.6500 - val_loss: 0.6263 - learning_rate: 5.0000e-04
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.7006 - loss: 0.6616 - val_accuracy: 0.6000 - val_loss: 0.6684 - learning_rate: 5.0000e-04
# Précision de validation pour le pli 1: 65.00%
# Évaluation avec 256 filtres
# Traitement du pli 1/10
# Définition du modèle avec 256 filtres...
# Modèle défini.
# Modèle compilé
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 175s 26s/step - accuracy: 0.5122 - loss: 2.2785 - val_accuracy: 0.5000 - val_loss: 0.7049 - learning_rate: 0.0010
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 149s 24s/step - accuracy: 0.5312 - loss: 0.7507 - val_accuracy: 0.5000 - val_loss: 0.6928 - learning_rate: 0.0010
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 151s 25s/step - accuracy: 0.5023 - loss: 0.6937 - val_accuracy: 0.5000 - val_loss: 0.6878 - learning_rate: 0.0010
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 169s 29s/step - accuracy: 0.5356 - loss: 0.7653 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 144s 23s/step - accuracy: 0.5191 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 144s 23s/step - accuracy: 0.5077 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 7/10
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 1:24 17s/step - accuracy: 0.6500 - loss: 0.6928

# %%
def plot_learning_curves(history):
        plt.figure(figsize=(12, 6))
        plt.subplot(1, 2, 1)
        plt.plot(history.history['loss'], label='Perte d\'entraînement')
        plt.plot(history.history['val_loss'], label='Perte de validation')
        plt.xlabel('Époques')
        plt.ylabel('Perte')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(history.history['accuracy'], label='Précision d\'entraînement')
        plt.plot(history.history['val_accuracy'], label='Précision de validation')
        plt.xlabel('Époques')
        plt.ylabel('Précision')
        plt.legend()

        plt.tight_layout()
        plt.show()

plot_learning_curves(history)

# %%
def matrice_de_confusion():
    y_pred = (model.predict(x_val_fold) > 0.5).astype("int32")
    cm = confusion_matrix(y_val_fold, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['PNEUMONIA', 'NORMAL'], yticklabels=['PNEUMONIA', 'NORMAL'])
    plt.ylabel('Réel')
    plt.xlabel('Prévu')
    plt.title(f'Matrice de confusion pour le pli {fold}')
    plt.show()

matrice_de_confusion()

# %%
def roc():
    fpr, tpr, _ = roc_curve(y_val_fold, (model.predict(x_val_fold) > 0.5).astype("int32"))
        roc_auc = auc(fpr, tpr)
        plt.figure()
        plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Courbe ROC (aire = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlabel('Taux de Faux Positifs')
        plt.ylabel('Taux de Vrais Positifs')
        plt.title(f'Courbe ROC pour le pli {fold}')
        plt.legend(loc='lower right')
        plt.show()

        fold += 1

roc()

print(f"Précision moyenne pour {n_filters} filtres: {np.mean(fold_accuracies)*100:.2f}%")
print(f"Temps d'entraînement moyen pour {n_filters} filtres: {np.mean(training_times):.2f} secondes\n")

# %%
def train_model_with_very_high_number_of_filters():
    best_n_filters = max(filter_numbers)
    print(f"Entraînement du modèle final avec {best_n_filters} filtres...")
    datagen = ImageDataGenerator(zoom_range=0.1, shear_range=0.1)
    datagen.fit(x_train)
    model_final = create_model(best_n_filters)
    
    start_time = time.time()
    history_final = model_final.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                                    epochs=epochs,
                                    validation_split=0.2,
                                    callbacks=[reduce_lr, early_stop])
    end_time = time.time()
    
    training_time_final = end_time - start_time
    print(f"Temps d'entraînement final: {training_time_final:.2f} secondes")

train_model_with_very_high_number_of_filters()

# %%
scores_final = model_final.evaluate(x_train, y_train, verbose=0)
print(f"Précision finale: {scores_final[1]*100:.2f}%")

# %%
plot_learning_curves(history_final)

# %%
def matrice_de_confusion2():
    y_pred_final = (model_final.predict(x_train) > 0.5).astype("int32")
    cm_final = confusion_matrix(y_train, y_pred_final)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_final, annot=True, fmt='d', cmap='Blues', xticklabels=['PNEUMONIA', 'NORMAL'], yticklabels=['PNEUMONIA', 'NORMAL'])
    plt.ylabel('Réel')
    plt.xlabel('Prévu')
    plt.title('Matrice de confusion - Modèle final')
    plt.show()

matrice_de_confusion2()

# %%
def roc2():
    fpr_final, tpr_final, _final = roc_curve(y_train, (model_final.predict(x_train) > 0.5).astype("int32"))
    roc_auc_final = auc(fpr_final, tpr_final)
    plt.figure()
    plt.plot(fpr_final, tpr_final, color='darkorange', lw=2, label=f'Courbe ROC (aire = {roc_auc_final:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('Taux de Faux Positifs')
    plt.ylabel('Taux de Vrais Positifs')
    plt.title('Courbe ROC - Modèle final')
    plt.legend(loc='lower right')
    plt.show()

roc2()

# %%
# Fonction pour afficher les prédictions
def display_predictions_simple(model, x_data, y_data, num_images=5):
    print("Affichage des prédictions simples...")
    predictions = (model.predict(x_data) > 0.5).astype("int32")
    plt.figure(figsize=(12, 6))
    for i in range(num_images):
        plt.subplot(1, num_images, i+1)
        plt.imshow(x_data[i].astype(np.uint8))
        plt.title(f"Vrai: {['PNEUMONIA', 'NORMAL'][y_data[i]]}\nPréd: {['PNEUMONIA', 'NORMAL'][predictions[i][0]]}")
        plt.axis('off')
    plt.show()

display_predictions_simple(model_final, x_train, y_train)

# %%
# Fonction pour afficher l'histogramme des prédictions
def plot_prediction_histogram(model, x_data, bins=20):
    print("Affichage de l'histogramme des prédictions...")
    predictions = model.predict(x_data)
    plt.hist(predictions, bins=bins, edgecolor='black')
    plt.xlabel('Probabilités prédites')
    plt.ylabel('Nombre d\'échantillons')
    plt.title('Histogramme des probabilités prédites')
    plt.show()

plot_prediction_histogram(model_final, x_train)
